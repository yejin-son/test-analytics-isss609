# %% [markdown]
# # Sentiment Analysis (Model evaluation)
# ## On Covid related articles

# %% [markdown]
# #### Load Dataset

# %%
import pandas as pd
airline_raw = pd.read_csv("./flightglobal_cleaned.csv")

# %%
df = pd.DataFrame(airline_raw)
df = df.dropna()
df = df[df['Topic'].str.contains("Coronavirus")]

airline_Title = df['Title'].fillna("")
airline_Article = df['Article'].fillna("")

# %%
df = df.reset_index(drop=True)
df
# Out:
#      Unnamed: 0                                           PageLink  \
# 0             1  https://www.flightglobal.com/fleets/tap-to-cut...
# 1            11  https://www.flightglobal.com/fleets/lufthansas...
# 2            12  https://www.flightglobal.com/airlines/sas-deta...
# 3            16  https://www.flightglobal.com/fleets/norwegian-...
# 4            22  https://www.flightglobal.com/networks/porter-a...
# ..          ...                                                ...
# 703        2078  https://www.flightglobal.com/networks/british-...
# 704        2082  https://www.flightglobal.com/networks/united-s...
# 705        2086  https://www.flightglobal.com/airlines/hong-kon...
# 706        2105  https://www.flightglobal.com/air-transport/eas...
# 707        2150  https://www.flightglobal.com/networks/asian-ca...
#
#                                                  Title  \
# 0             TAP to cut more aircraft as losses mount
# 1    Lufthansa's reactivated fleet to reach 380 air...
# 2    SAS details extensive make-or-break recapitali...
# 3          Norwegian cancels 97 Boeing aircraft orders
# 4          Porter Airlines delays restart to 31 August
# ..                                                 ...
# 703  British Airways suspends mainland Chinese serv...
# 704              United suspends some flights to China
# 705    Hong Kong carriers to halve capacity into China
# 706  EASA issues safety bulletin on Wuhan coronavir...
# 707  Asian carriers suspend Wuhan flights in wake o...
#
#                                                Article       Date  \
# 0    TAP Air Portugal has disclosed plans to furthe...  30-Jun-20
# 1    Lufthansa Group plans to have reactivated half...  30-Jun-20
# 2    Scandinavian operator SAS has detailed a recap...  30-Jun-20
# 3    Norwegian has cancelled orders for 97 Boeing a...  30-Jun-20
# 4    Canada's Porter Airlines will restart its oper...  30-Jun-20
# ..                                                 ...        ...
# 703  British Airways is temporarily suspending all ...  29-Jan-20
# 704  Citing a significant drop in load factors, Uni...  29-Jan-20
# 705  Hong Kong's four main carriers will halve thei...  29-Jan-20
# 706  As the spread of the novel coronavirus (2019-n...  28-Jan-20
# 707  Several Asian carriers have suspended flights ...  23-Jan-20
#
#                                                  Topic
# 0                Coronavirus, Europe, Fleets, Networks
# 1                Coronavirus, Europe, Fleets, Networks
# 2              Air Transport, Coronavirus, Europe, SAS
# 3    Airframers, Airlines, Coronavirus, Europe, Fle...
# 4    Airlines, Coronavirus, Networks, North America...
# ..                                                 ...
# 703  Air Transport, Airlines, Asia Pacific, Coronav...
# 704      Airlines, Asia Pacific, Coronavirus, Networks
# 705  Cathay Dragon, Cathay Pacific, China, Coronavi...
# 706                         China, Coronavirus, Europe
# 707      Airlines, Asia Pacific, Coronavirus, Networks
#
# [708 rows x 6 columns]

# %% [markdown]
# ### 1) Using Lexicon by Hu and Liu

# %% [markdown]
# ###### Tokenization and Lowercasing

# %%
from nltk.tokenize import word_tokenize

df['Month'] = pd.DatetimeIndex(df['Date']).month
df2 = df[['PageLink','Title','Article','Month','Topic']]

#tokenize
df2['sent'] = df['Article'].apply(word_tokenize)  


#lowercase
def lower(row):
    lower = [w.lower() for w in row['sent']]
    return lower

df2['sent'] = df2.apply(lower,axis=1)

df2.head()
# Out:
# C:\Users\Angeline Jiang\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\Angeline Jiang\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
#                                             PageLink  \
# 0  https://www.flightglobal.com/fleets/tap-to-cut...
# 1  https://www.flightglobal.com/fleets/lufthansas...
# 2  https://www.flightglobal.com/airlines/sas-deta...
# 3  https://www.flightglobal.com/fleets/norwegian-...
# 4  https://www.flightglobal.com/networks/porter-a...
#
#                                                Title  \
# 0           TAP to cut more aircraft as losses mount
# 1  Lufthansa's reactivated fleet to reach 380 air...
# 2  SAS details extensive make-or-break recapitali...
# 3        Norwegian cancels 97 Boeing aircraft orders
# 4        Porter Airlines delays restart to 31 August
#
#                                              Article  Month  \
# 0  TAP Air Portugal has disclosed plans to furthe...      6
# 1  Lufthansa Group plans to have reactivated half...      6
# 2  Scandinavian operator SAS has detailed a recap...      6
# 3  Norwegian has cancelled orders for 97 Boeing a...      6
# 4  Canada's Porter Airlines will restart its oper...      6
#
#                                                Topic  \
# 0              Coronavirus, Europe, Fleets, Networks
# 1              Coronavirus, Europe, Fleets, Networks
# 2            Air Transport, Coronavirus, Europe, SAS
# 3  Airframers, Airlines, Coronavirus, Europe, Fle...
# 4  Airlines, Coronavirus, Networks, North America...
#
#                                                 sent
# 0  [tap, air, portugal, has, disclosed, plans, to...
# 1  [lufthansa, group, plans, to, have, reactivate...
# 2  [scandinavian, operator, sas, has, detailed, a...
# 3  [norwegian, has, cancelled, orders, for, 97, b...
# 4  [canada, 's, porter, airlines, will, restart, ...

# %% [markdown]
# ##### Lemmatization

# %%
import nltk
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer

#POS Tagging

#Mapping of NLTK’s POS tags to the format wordnet lemmatizer would accept. 
#The get_wordnet_pos() function defined below does this mapping job.

def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
#     print(tag)
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}
#     print(tag_dict)
    return tag_dict.get(tag, wordnet.NOUN)


#Lemmatization with WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

def lemma(row):
    lem = ([lemmatizer.lemmatize(w, get_wordnet_pos(w)) for w in row['sent']])
    return lem


df2['lem'] = df2.apply(lemma,axis =1)
df2.head()
# Out:
#                                             PageLink  \
# 0  https://www.flightglobal.com/fleets/tap-to-cut...
# 1  https://www.flightglobal.com/fleets/lufthansas...
# 2  https://www.flightglobal.com/airlines/sas-deta...
# 3  https://www.flightglobal.com/fleets/norwegian-...
# 4  https://www.flightglobal.com/networks/porter-a...
#
#                                                Title  \
# 0           TAP to cut more aircraft as losses mount
# 1  Lufthansa's reactivated fleet to reach 380 air...
# 2  SAS details extensive make-or-break recapitali...
# 3        Norwegian cancels 97 Boeing aircraft orders
# 4        Porter Airlines delays restart to 31 August
#
#                                              Article  Month  \
# 0  TAP Air Portugal has disclosed plans to furthe...      6
# 1  Lufthansa Group plans to have reactivated half...      6
# 2  Scandinavian operator SAS has detailed a recap...      6
# 3  Norwegian has cancelled orders for 97 Boeing a...      6
# 4  Canada's Porter Airlines will restart its oper...      6
#
#                                                Topic  \
# 0              Coronavirus, Europe, Fleets, Networks
# 1              Coronavirus, Europe, Fleets, Networks
# 2            Air Transport, Coronavirus, Europe, SAS
# 3  Airframers, Airlines, Coronavirus, Europe, Fle...
# 4  Airlines, Coronavirus, Networks, North America...
#
#                                                 sent  \
# 0  [tap, air, portugal, has, disclosed, plans, to...
# 1  [lufthansa, group, plans, to, have, reactivate...
# 2  [scandinavian, operator, sas, has, detailed, a...
# 3  [norwegian, has, cancelled, orders, for, 97, b...
# 4  [canada, 's, porter, airlines, will, restart, ...
#
#                                                  lem
# 0  [tap, air, portugal, have, disclose, plan, to,...
# 1  [lufthansa, group, plan, to, have, reactivate,...
# 2  [scandinavian, operator, sa, have, detailed, a...
# 3  [norwegian, have, cancel, order, for, 97, boei...
# 4  [canada, 's, porter, airline, will, restart, i...

# %% [markdown]
# ##### Load Positive and Negative Lexicons

# %%
pos_lexicon = './positive-words.txt'
neg_lexicon = './negative-words.txt' 


# Read the positive sentiment lexicon.
pos_dict = {}
f = open(pos_lexicon, 'r', encoding = "ISO-8859-1")
for line in f:
    line = line.strip()
    pos_dict[line] = 1
f.close()

# Read the negative sentiment lexicon.
neg_dict = {}
f = open(neg_lexicon, 'r', encoding = "ISO-8859-1")
for line in f:
    line = line.strip()
    neg_dict[line] = 1
f.close()

# %% [markdown]
# ##### Scoring and Sentiment Labeling

# %%
def f(row):
    score = 0
    for word in row['lem']:
    
# If the word w is inside the positive lexicon, then increase the score by 1.
        if word in pos_dict:
            score = score + 1

# If the word w is inside the negative lexicon, then decrease the score by 1.

        elif word in neg_dict:
            score = score - 1

    return score


def f1(row):
    if row['score'] > 0:
        sentiment = 'positive'
        
    elif row['score'] <0:
        sentiment = 'negative'
        
    else:
        sentiment = 'neutral'
    
    
    return sentiment

# %%
df2['score'] = df2.apply(f, axis=1)
df2['sentiment_lexicon'] = df2.apply(f1, axis=1)

df2
# Out:
#                                               PageLink  \
# 0    https://www.flightglobal.com/fleets/tap-to-cut...
# 1    https://www.flightglobal.com/fleets/lufthansas...
# 2    https://www.flightglobal.com/airlines/sas-deta...
# 3    https://www.flightglobal.com/fleets/norwegian-...
# 4    https://www.flightglobal.com/networks/porter-a...
# ..                                                 ...
# 703  https://www.flightglobal.com/networks/british-...
# 704  https://www.flightglobal.com/networks/united-s...
# 705  https://www.flightglobal.com/airlines/hong-kon...
# 706  https://www.flightglobal.com/air-transport/eas...
# 707  https://www.flightglobal.com/networks/asian-ca...
#
#                                                  Title  \
# 0             TAP to cut more aircraft as losses mount
# 1    Lufthansa's reactivated fleet to reach 380 air...
# 2    SAS details extensive make-or-break recapitali...
# 3          Norwegian cancels 97 Boeing aircraft orders
# 4          Porter Airlines delays restart to 31 August
# ..                                                 ...
# 703  British Airways suspends mainland Chinese serv...
# 704              United suspends some flights to China
# 705    Hong Kong carriers to halve capacity into China
# 706  EASA issues safety bulletin on Wuhan coronavir...
# 707  Asian carriers suspend Wuhan flights in wake o...
#
#                                                Article  Month  \
# 0    TAP Air Portugal has disclosed plans to furthe...      6
# 1    Lufthansa Group plans to have reactivated half...      6
# 2    Scandinavian operator SAS has detailed a recap...      6
# 3    Norwegian has cancelled orders for 97 Boeing a...      6
# 4    Canada's Porter Airlines will restart its oper...      6
# ..                                                 ...    ...
# 703  British Airways is temporarily suspending all ...      1
# 704  Citing a significant drop in load factors, Uni...      1
# 705  Hong Kong's four main carriers will halve thei...      1
# 706  As the spread of the novel coronavirus (2019-n...      1
# 707  Several Asian carriers have suspended flights ...      1
#
#                                                  Topic  \
# 0                Coronavirus, Europe, Fleets, Networks
# 1                Coronavirus, Europe, Fleets, Networks
# 2              Air Transport, Coronavirus, Europe, SAS
# 3    Airframers, Airlines, Coronavirus, Europe, Fle...
# 4    Airlines, Coronavirus, Networks, North America...
# ..                                                 ...
# 703  Air Transport, Airlines, Asia Pacific, Coronav...
# 704      Airlines, Asia Pacific, Coronavirus, Networks
# 705  Cathay Dragon, Cathay Pacific, China, Coronavi...
# 706                         China, Coronavirus, Europe
# 707      Airlines, Asia Pacific, Coronavirus, Networks
#
#                                                   sent  \
# 0    [tap, air, portugal, has, disclosed, plans, to...
# 1    [lufthansa, group, plans, to, have, reactivate...
# 2    [scandinavian, operator, sas, has, detailed, a...
# 3    [norwegian, has, cancelled, orders, for, 97, b...
# 4    [canada, 's, porter, airlines, will, restart, ...
# ..                                                 ...
# 703  [british, airways, is, temporarily, suspending...
# 704  [citing, a, significant, drop, in, load, facto...
# 705  [hong, kong, 's, four, main, carriers, will, h...
# 706  [as, the, spread, of, the, novel, coronavirus,...
# 707  [several, asian, carriers, have, suspended, fl...
#
#                                                    lem  score  \
# 0    [tap, air, portugal, have, disclose, plan, to,...      4
# 1    [lufthansa, group, plan, to, have, reactivate,...      0
# 2    [scandinavian, operator, sa, have, detailed, a...      1
# 3    [norwegian, have, cancel, order, for, 97, boei...     -3
# 4    [canada, 's, porter, airline, will, restart, i...     -4
# ..                                                 ...    ...
# 703  [british, airway, be, temporarily, suspend, al...     -3
# 704  [cite, a, significant, drop, in, load, factor,...      8
# 705  [hong, kong, 's, four, main, carrier, will, ha...    -10
# 706  [a, the, spread, of, the, novel, coronavirus, ...      1
# 707  [several, asian, carrier, have, suspend, fligh...     -6
#
#     sentiment_lexicon
# 0            positive
# 1             neutral
# 2            positive
# 3            negative
# 4            negative
# ..                ...
# 703          negative
# 704          positive
# 705          negative
# 706          positive
# 707          negative
#
# [708 rows x 9 columns]

# %% [markdown]
# ##### Breakdown of Results

# %%
#Find proportion of sentiments
df2['sentiment_lexicon'].value_counts(normalize = True)
# Out:
# negative    0.468927
# positive    0.446328
# neutral     0.084746
# Name: sentiment_lexicon, dtype: float64

# %%
#See sentiments by month
pd.crosstab(df2.Month, df2.sentiment_lexicon,  margins=True)
# Out:
# sentiment_lexicon  negative  neutral  positive  All
# Month
# 1                         7        0         3   10
# 2                        23        2         3   28
# 3                       138       22       110  270
# 4                        92       18       109  219
# 5                        36       15        43   94
# 6                        36        3        48   87
# All                     332       60       316  708

# %% [markdown]
# ### 2) Using SentiWordNet

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from nltk.corpus import sentiwordnet as swn
from nltk import sent_tokenize, word_tokenize, pos_tag
import nltk
# nltk.download('sentiwordnet')
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# ##### Functions for SentiWordNet

# %%
def penn_to_wn(tag):
#Convert between the PennTreebank tags to simple Wordnet tags

    if tag.startswith('J'):
        return wn.ADJ
    elif tag.startswith('N'):
        return wn.NOUN
    elif tag.startswith('R'):
        return wn.ADV
    elif tag.startswith('V'):
        return wn.VERB
    return None


#Score first synset of each word
def sentiment_sentiwordnet(row):
    sentiment = 0
    tokens_count = 0

    tagged_sentence = pos_tag(row['sent'])

    for word, tag in tagged_sentence:
        wn_tag = penn_to_wn(tag)
        if wn_tag not in (wn.NOUN, wn.ADJ, wn.ADV,wn.VERB):
            continue

        lemma = lemmatizer.lemmatize(word, pos=wn_tag)
        if not lemma:
            continue

        synsets = wn.synsets(lemma, pos=wn_tag)
        if not synsets:
            continue

        synset = synsets[0]
        swn_synset = swn.senti_synset(synset.name())
        word_sent = swn_synset.pos_score() - swn_synset.neg_score()

        if word_sent != 0:
            sentiment += word_sent
            tokens_count += 1

    if tokens_count == 0:
        return 0
    sentiment = sentiment/tokens_count
    return sentiment



#Sentiment label
def f1(row):
    if row['sentiment score'] > 0.01:
        sentiment = 'positive'
        
    elif row['sentiment score'] <-0.01:
        sentiment = 'negative'
        
    else:
        sentiment = 'neutral'
    
    
    return sentiment

# %% [markdown]
# ##### Tokenization and Lowercasing

# %%
df1 = df[['Month','PageLink','Article']]

#tokenize
df1['sent'] = df1['Article'].apply(word_tokenize)  


#lowercase
def lower(row):
    lower = [w.lower() for w in row['sent']]
    return lower

df1['sent'] = df1.apply(lower,axis=1)

df1.head()
# Out:
# C:\Users\Angeline Jiang\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Angeline Jiang\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
#    Month                                           PageLink  \
# 0      6  https://www.flightglobal.com/fleets/tap-to-cut...
# 1      6  https://www.flightglobal.com/fleets/lufthansas...
# 2      6  https://www.flightglobal.com/airlines/sas-deta...
# 3      6  https://www.flightglobal.com/fleets/norwegian-...
# 4      6  https://www.flightglobal.com/networks/porter-a...
#
#                                              Article  \
# 0  TAP Air Portugal has disclosed plans to furthe...
# 1  Lufthansa Group plans to have reactivated half...
# 2  Scandinavian operator SAS has detailed a recap...
# 3  Norwegian has cancelled orders for 97 Boeing a...
# 4  Canada's Porter Airlines will restart its oper...
#
#                                                 sent
# 0  [tap, air, portugal, has, disclosed, plans, to...
# 1  [lufthansa, group, plans, to, have, reactivate...
# 2  [scandinavian, operator, sas, has, detailed, a...
# 3  [norwegian, has, cancelled, orders, for, 97, b...
# 4  [canada, 's, porter, airlines, will, restart, ...

# %% [markdown]
# ##### Sentiment scoring

# %%
df1['sentiment score'] = df1.apply(sentiment_sentiwordnet,axis=1)
df1['sentiment_swn'] = df1.apply(f1,axis=1)

df1
# Out:
# C:\Users\Angeline Jiang\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Angeline Jiang\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Month                                           PageLink  \
# 0        6  https://www.flightglobal.com/fleets/tap-to-cut...
# 1        6  https://www.flightglobal.com/fleets/lufthansas...
# 2        6  https://www.flightglobal.com/airlines/sas-deta...
# 3        6  https://www.flightglobal.com/fleets/norwegian-...
# 4        6  https://www.flightglobal.com/networks/porter-a...
# ..     ...                                                ...
# 703      1  https://www.flightglobal.com/networks/british-...
# 704      1  https://www.flightglobal.com/networks/united-s...
# 705      1  https://www.flightglobal.com/airlines/hong-kon...
# 706      1  https://www.flightglobal.com/air-transport/eas...
# 707      1  https://www.flightglobal.com/networks/asian-ca...
#
#                                                Article  \
# 0    TAP Air Portugal has disclosed plans to furthe...
# 1    Lufthansa Group plans to have reactivated half...
# 2    Scandinavian operator SAS has detailed a recap...
# 3    Norwegian has cancelled orders for 97 Boeing a...
# 4    Canada's Porter Airlines will restart its oper...
# ..                                                 ...
# 703  British Airways is temporarily suspending all ...
# 704  Citing a significant drop in load factors, Uni...
# 705  Hong Kong's four main carriers will halve thei...
# 706  As the spread of the novel coronavirus (2019-n...
# 707  Several Asian carriers have suspended flights ...
#
#                                                   sent  sentiment score  \
# 0    [tap, air, portugal, has, disclosed, plans, to...         0.057927
# 1    [lufthansa, group, plans, to, have, reactivate...         0.077703
# 2    [scandinavian, operator, sas, has, detailed, a...         0.058594
# 3    [norwegian, has, cancelled, orders, for, 97, b...         0.053241
# 4    [canada, 's, porter, airlines, will, restart, ...         0.115196
# ..                                                 ...              ...
# 703  [british, airways, is, temporarily, suspending...        -0.044643
# 704  [citing, a, significant, drop, in, load, facto...        -0.153846
# 705  [hong, kong, 's, four, main, carriers, will, h...        -0.032500
# 706  [as, the, spread, of, the, novel, coronavirus,...         0.006579
# 707  [several, asian, carriers, have, suspended, fl...         0.006944
#
#     sentiment_swn
# 0        positive
# 1        positive
# 2        positive
# 3        positive
# 4        positive
# ..            ...
# 703      negative
# 704      negative
# 705      negative
# 706       neutral
# 707       neutral
#
# [708 rows x 6 columns]

# %% [markdown]
# ##### Breakdown of Results

# %%
#Find proportion of sentiments
df1['sentiment_swn'].value_counts(normalize = True)
# Out:
# positive    0.690678
# negative    0.206215
# neutral     0.103107
# Name: sentiment_swn, dtype: float64

# %%
#See sentiments by month
pd.crosstab(df1.Month, df1.sentiment_swn,  margins=True)
# Out:
# sentiment_swn  negative  neutral  positive  All
# Month
# 1                     5        3         2   10
# 2                     6        5        17   28
# 3                    67       27       176  270
# 4                    41       21       157  219
# 5                    12        5        77   94
# 6                    15       12        60   87
# All                 146       73       489  708

# %% [markdown]
# ### 3) Using Vader

# %% [markdown]
# ###### Lowercasing and Sentiment scoring

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA

sia = SIA()
resultsTitle = []
resultsArticle = []

for Article in airline_Article:
    Article = Article.lower()
    pol_score = sia.polarity_scores(Article)
    pol_score['airline_Article'] = Article
    resultsArticle.append(pol_score)

# %%
dfArticle = pd.DataFrame.from_records(resultsArticle)
dfArticle = dfArticle .rename({"neg": "Neg_Base_A", "neu": "Neu_Base_A", "pos": "Pos_Base_A", "compound": "Compound_Base_A"}, axis=1)
dfArticle
# Out:
#      Neg_Base_A  Neu_Base_A  Pos_Base_A  Compound_Base_A  \
# 0         0.044       0.905       0.051           0.5267
# 1         0.016       0.936       0.048           0.8990
# 2         0.040       0.858       0.102           0.9744
# 3         0.057       0.908       0.036          -0.8706
# 4         0.044       0.891       0.065           0.5605
# ..          ...         ...         ...              ...
# 703       0.070       0.876       0.054          -0.4357
# 704       0.025       0.912       0.063           0.8151
# 705       0.030       0.941       0.029          -0.2732
# 706       0.042       0.876       0.082           0.9325
# 707       0.055       0.920       0.025          -0.7003
#
#                                        airline_Article
# 0    tap air portugal has disclosed plans to furthe...
# 1    lufthansa group plans to have reactivated half...
# 2    scandinavian operator sas has detailed a recap...
# 3    norwegian has cancelled orders for 97 boeing a...
# 4    canada's porter airlines will restart its oper...
# ..                                                 ...
# 703  british airways is temporarily suspending all ...
# 704  citing a significant drop in load factors, uni...
# 705  hong kong's four main carriers will halve thei...
# 706  as the spread of the novel coronavirus (2019-n...
# 707  several asian carriers have suspended flights ...
#
# [708 rows x 5 columns]

# %%
airline_raw2 = pd.concat([df, dfArticle], axis=1)
airline_raw2 = airline_raw2.drop(['airline_Article'], axis=1)
airline_raw2['Date'] = pd.to_datetime(airline_raw2['Date'])
airline_raw2['Month'] = airline_raw2['Date'].dt.month

airline_raw2['Senti_Base_A'] = 'Neutral'
airline_raw2.loc[airline_raw2['Compound_Base_A'] > 0, 'Senti_Base_A'] = 'Positive'
airline_raw2.loc[airline_raw2['Compound_Base_A'] < 0, 'Senti_Base_A'] = 'Negative'

# %%
airline_raw2
# Out:
#      Unnamed: 0                                           PageLink  \
# 0             1  https://www.flightglobal.com/fleets/tap-to-cut...
# 1            11  https://www.flightglobal.com/fleets/lufthansas...
# 2            12  https://www.flightglobal.com/airlines/sas-deta...
# 3            16  https://www.flightglobal.com/fleets/norwegian-...
# 4            22  https://www.flightglobal.com/networks/porter-a...
# ..          ...                                                ...
# 703        2078  https://www.flightglobal.com/networks/british-...
# 704        2082  https://www.flightglobal.com/networks/united-s...
# 705        2086  https://www.flightglobal.com/airlines/hong-kon...
# 706        2105  https://www.flightglobal.com/air-transport/eas...
# 707        2150  https://www.flightglobal.com/networks/asian-ca...
#
#                                                  Title  \
# 0             TAP to cut more aircraft as losses mount
# 1    Lufthansa's reactivated fleet to reach 380 air...
# 2    SAS details extensive make-or-break recapitali...
# 3          Norwegian cancels 97 Boeing aircraft orders
# 4          Porter Airlines delays restart to 31 August
# ..                                                 ...
# 703  British Airways suspends mainland Chinese serv...
# 704              United suspends some flights to China
# 705    Hong Kong carriers to halve capacity into China
# 706  EASA issues safety bulletin on Wuhan coronavir...
# 707  Asian carriers suspend Wuhan flights in wake o...
#
#                                                Article       Date  \
# 0    TAP Air Portugal has disclosed plans to furthe... 2020-06-30
# 1    Lufthansa Group plans to have reactivated half... 2020-06-30
# 2    Scandinavian operator SAS has detailed a recap... 2020-06-30
# 3    Norwegian has cancelled orders for 97 Boeing a... 2020-06-30
# 4    Canada's Porter Airlines will restart its oper... 2020-06-30
# ..                                                 ...        ...
# 703  British Airways is temporarily suspending all ... 2020-01-29
# 704  Citing a significant drop in load factors, Uni... 2020-01-29
# 705  Hong Kong's four main carriers will halve thei... 2020-01-29
# 706  As the spread of the novel coronavirus (2019-n... 2020-01-28
# 707  Several Asian carriers have suspended flights ... 2020-01-23
#
#                                                  Topic  Month  Neg_Base_A  \
# 0                Coronavirus, Europe, Fleets, Networks      6       0.044
# 1                Coronavirus, Europe, Fleets, Networks      6       0.016
# 2              Air Transport, Coronavirus, Europe, SAS      6       0.040
# 3    Airframers, Airlines, Coronavirus, Europe, Fle...      6       0.057
# 4    Airlines, Coronavirus, Networks, North America...      6       0.044
# ..                                                 ...    ...         ...
# 703  Air Transport, Airlines, Asia Pacific, Coronav...      1       0.070
# 704      Airlines, Asia Pacific, Coronavirus, Networks      1       0.025
# 705  Cathay Dragon, Cathay Pacific, China, Coronavi...      1       0.030
# 706                         China, Coronavirus, Europe      1       0.042
# 707      Airlines, Asia Pacific, Coronavirus, Networks      1       0.055
#
#      Neu_Base_A  Pos_Base_A  Compound_Base_A Senti_Base_A
# 0         0.905       0.051           0.5267     Positive
# 1         0.936       0.048           0.8990     Positive
# 2         0.858       0.102           0.9744     Positive
# 3         0.908       0.036          -0.8706     Negative
# 4         0.891       0.065           0.5605     Positive
# ..          ...         ...              ...          ...
# 703       0.876       0.054          -0.4357     Negative
# 704       0.912       0.063           0.8151     Positive
# 705       0.941       0.029          -0.2732     Negative
# 706       0.876       0.082           0.9325     Positive
# 707       0.920       0.025          -0.7003     Negative
#
# [708 rows x 12 columns]

# %% [markdown]
# ##### Breakdown of Results

# %%
#Find proportion of sentiments
airline_raw2['Senti_Base_A'].value_counts(normalize = True)
# Out:
# Positive    0.552260
# Negative    0.446328
# Neutral     0.001412
# Name: Senti_Base_A, dtype: float64

# %%
pd.crosstab(airline_raw2.Month, airline_raw2.Senti_Base_A)
# Out:
# Senti_Base_A  Negative  Neutral  Positive
# Month
# 1                    5        0         5
# 2                   20        0         8
# 3                  136        0       134
# 4                   94        1       124
# 5                   32        0        62
# 6                   29        0        58

# %%
pd.crosstab(airline_raw2.Month, airline_raw2.Senti_Base_A).apply(lambda r: round(r/r.sum(),2), axis=1)
# Out:
# Senti_Base_A  Negative  Neutral  Positive
# Month
# 1                 0.50      0.0      0.50
# 2                 0.71      0.0      0.29
# 3                 0.50      0.0      0.50
# 4                 0.43      0.0      0.57
# 5                 0.34      0.0      0.66
# 6                 0.33      0.0      0.67

# %% [markdown]
# ### 4) Using TextBlob

# %% [markdown]
# ##### Sentiment scoring

# %%
from textblob import TextBlob

resultsArticletb = []
pol_score_article = {}

for Article in airline_Article:
    Article = Article.lower()
    article = TextBlob(Article)
    pol_score_article['polarity'] = article.sentiment.polarity
    pol_score_article['subjectivity'] = article.sentiment.subjectivity
    pol_score_article['airline_Article'] = Article
    resultsArticletb.append(pol_score_article.copy())

# %%
dfArticletb = pd.DataFrame.from_records(resultsArticletb)
dfArticletb = dfArticletb.rename({"polarity": "Polarity_Base_A", "subjectivity": "Subjectivity_Base_A"}, axis=1)

# %%
airline_raw2_tb = pd.concat([df, dfArticletb], axis=1)
airline_raw2_tb = airline_raw2_tb.drop(['airline_Article'], axis=1)
airline_raw2_tb['Date'] = pd.to_datetime(airline_raw2_tb['Date'])
airline_raw2_tb['Month'] = airline_raw2_tb['Date'].dt.month

airline_raw2_tb['Senti_Base_A'] = 'Neutral'
airline_raw2_tb.loc[airline_raw2_tb['Polarity_Base_A'] > 0, 'Senti_Base_A'] = 'Positive'
airline_raw2_tb.loc[airline_raw2_tb['Polarity_Base_A'] < 0, 'Senti_Base_A'] = 'Negative'

# %% [markdown]
# ##### Breakdown of Results

# %%
#Find proportion of sentiments
airline_raw2_tb['Senti_Base_A'].value_counts(normalize = True)
# Out:
# Positive    0.865819
# Negative    0.128531
# Neutral     0.005650
# Name: Senti_Base_A, dtype: float64

# %%
pd.crosstab(airline_raw2_tb.Month, airline_raw2_tb.Senti_Base_A)
# Out:
# Senti_Base_A  Negative  Neutral  Positive
# Month
# 1                    1        0         9
# 2                    4        0        24
# 3                   38        1       231
# 4                   35        2       182
# 5                    8        0        86
# 6                    5        1        81

# %%
pd.crosstab(airline_raw2_tb.Month, airline_raw2_tb.Senti_Base_A).apply(lambda r: round(r/r.sum(),2), axis=1)
# Out:
# Senti_Base_A  Negative  Neutral  Positive
# Month
# 1                 0.10     0.00      0.90
# 2                 0.14     0.00      0.86
# 3                 0.14     0.00      0.86
# 4                 0.16     0.01      0.83
# 5                 0.09     0.00      0.91
# 6                 0.06     0.01      0.93
